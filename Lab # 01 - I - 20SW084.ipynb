# %%
# Lab no 01 : Python Basics

# %%
# Submitted By: Junaid aslam (20SW084)           ---------------        Submitted to: Mam Rafia

# %%
#1 Base Types & Identifiers

id = 84
name = "Junaid\tRajput"
gpa = 3.03
male = True
bytess = bytes(name,"utf-8")

print(id)
print(type(name))
print(type(gpa))
print(type(bytess))
# Out:
# 84
# <class 'str'>
# <class 'float'>
# <class 'bytes'>

# %%
#2 Container Types

myList = ["yes" , "Mutable" , 84 , False , 4.0]
myTuple = ("no" , "Immutable" , 87 , True , 1.0)
myTuple2 = "jfdk" , 43 , 4.4
myDict = {"20SW078":"Musadik","20SW084":"Junaid","20SW106":"Ahsan"}
mySet = {"a" , "e" , "i" , "o" , "u"}

myList.append(myList)
myList.remove(4.0)
myList[2] = 7468   #  ----------      Mutable Nature
print(myList)

# myTuple[3] = 54     ----------     Immutable nature
print(myTuple)

print(myDict["20SW106"])
myDict["20SW078"]="Musadiq Bhutto"
myDict["20SW020"]="Khan"
print(len(myDict))
del myDict["20SW020"]
print(myDict)
myDict.clear()

print(mySet)
# Out:
# ['yes', 'Mutable', 7468, False, [...]]
# ('no', 'Immutable', 87, True, 1.0)
# Ahsan
# 4
# {'20SW078': 'Musadiq Bhutto', '20SW084': 'Junaid', '20SW106': 'Ahsan'}
# {'u', 'a', 'e', 'i', 'o'}

# %%
#3 Variables assignment

from collections.abc import Sequence

a = b = c = 92
x , y = 4 , 43

print(x)
print(y)

x , y = y , x

x += 3

print(x)

del x
# Out:
# 4
# 43
# 46

# %%
#4 Conversions

int(45)
int(438.3)
int("3f",16)
float(-11.84e9)
round(5.56, 1)
chr(64)
repr('x')
bytes([72,9,64])
list("abc")
":".join(["Hi","Hello", "True"])
"words with spaces".split(" ")
# Out:
# ['words', 'with', 'spaces']

# %%
#5 Sequence Containers Indexing

myList = [1,2,3,4,5]
print(myList[-5])
myList[:-1]
myList[1:-1]
myList[::2]
myList[::-1]
myList[::-2]
myList[:]
myList[:3]
myList[3:]
myList[-3:-1]
del myList[3]
# Out:
# 1

# %%
#6 Boolean Logic

a = True
b = False

a and b
a or b
not b
# Out:
# True

# %%
#7 Statement Blocks

if True:
    print(True)
else:
    print(False)
# 4 spaces indentation is necessary
# Out:
# True

# %%
#8 Modules / Name Import

import sys

print(sys.version)
# Out:
# 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]

# %%
#9 Conditional Statements

age = 56
if age<=18:
  print("Young")
elif age >=60:
  print("Retired")
else:
  print("active")
# Out:
# active

# %%
#10 Maths

from math import sin,pi,cos,sqrt,log,e,ceil,floor

(1+5.3)*2
abs(-3.2)
round(3.5733,1)
pow(4,3)
sin(pi/4)
cos(2*pi/3)
sqrt(121)
log(e**2)
ceil(12.5)
floor(12.5)
# Out:
# 12

# %%
#11 Exceptions on Errors

try:
  arithmetic = 5/0
  print(arithmetic)
except ArithmeticError:
  print('You have just made an Arithmetic error')
# Out:
# You have just made an Arithmetic error

# %%
#12 Conditional Loop Statement

s = 0
i = 1
while i <= 100:
  s = s + i**2
  i = i + 1
print("Sum is: " , s)

for i in range(5):
    if i == 3:
        break
    print(i)

for i in range(5):
    if i == 3:
        continue
    print(i)
# Out:
# Sum is:  338350
# 0
# 1
# 2
# 0
# 1
# 2
# 4

# %%
#13 Display & Input

print("V=",3,"cms")

s = input("instructions: ")
# Out:
# V= 3 cms
# instructions: Hello

# %%
#14 Iterative Loop Statement

s="Some Text"
cnt = 0
for var in s:
  if(var == "e"):
    cnt = cnt + 1
print("Found e ",cnt," times")
# Out:
# Found e  2  times

# %%
#15 Generic Operations in Containers

lst = [11,14,16,18,19]
lost = []
for idx in range(len(lst)):
  val = lst[idx]
  if val > 15:
    lost.append(val)
    lst[idx] = 15
print("modif: ",lst, "-lost: ",lost)


for idx,val in enumerate(lst):
  print(idx,"----",val)
# Out:
# modif:  [11, 14, 15, 15, 15] -lost:  [16, 18, 19]
# 0 ---- 11
# 1 ---- 14
# 2 ---- 15
# 3 ---- 15
# 4 ---- 15

# %%
#16 Integer Sequences

for i in range(5):
  print(i)

for j in range(2,8,2):
  print(j)

for k in range(20,5,-5):
  print(k)
# Out:
# 0
# 1
# 2
# 3
# 4
# 2
# 4
# 6
# 20
# 15
# 10

# %%
#17 Function Definition & Function Call

def sum(x,y):
  print("In Function Body")
  return x+y

print(sum(4,8))
# Out:
# In Function Body
# 12

# %%
#18 Generic Operations on Containers

lst = [114,104,16,187,19]

len(lst)
min(lst)
max(lst)
sum(lst)
sorted(lst)
all(lst)
any(lst)
enumerate(lst)
reversed(lst)
lst.index(16)
lst.count(16)

import copy
copy.copy(lst) # Shllow Copy
copy.deepcopy(lst) #Deep Copy
# Out:
# [114, 104, 16, 187, 19]

# %%
#19 Operations in Lists

lst = [114,104,16,187,19]

lst.append(92)
lst.extend([1,2,3])
lst.insert(34,2)
lst.remove(187)
lst.pop(3)
lst.sort()
lst.reverse()

print(lst)
# Out:
# [114, 104, 92, 16, 3, 2, 2, 1]

# %%
#20 Operations in Dictionaries

myDict = {"20SW078":"Musadik","20SW084":"Junaid","20SW106":"Ahsan"}

myDict.keys()
myDict.values()
myDict.items()
myDict.pop("20SW084")
myDict.popitem()
myDict.get("20SW078")
myDict.setdefault("20SW106")
# Out:
# ('20SW106', 'Ahsan')

# %%
#21 Operations on Sets

mySet1 = {"a" , "e" , "i" , "o" , "u"}
mySet2 = {"f" , "e" , "s" , "h" , "u"}

mySet1.update(mySet2)
mySet1.add("d")
mySet1.remove("u")
mySet1.discard("f")
mySet2.clear()
mySet1.pop()
print(mySet1)
# Out:
# {'a', 'd', 'i', 'e', 'o', 's'}

# %%
#22 Operations on Strings & Formatting

myStr = "Hello Google"

myStr.count('e')
myStr.capitalize()
myStr.startswith('o')
myStr.endswith('e')
myStr.strip('l')
myStr.partition('e')
myStr.index('o')
myStr.find('o')
myStr.isalpha()
myStr.upper()
myStr.lower()
myStr.swapcase()
myStr.casefold()
myStr.center(12)
myStr.encode()
myStr.ljust(65)

"{:+2.3f}".format(45.72793)
# Out:
# '+45.728'

# %%
#23 Files

f = open("file.txt","w",encoding = "utf8")
f.write("Hello")
f.flush()
f.truncate(1)
f.tell()
f.seek(2)
f.close()

f = open("file.txt","r",encoding = "utf8")
f.read()
f.close()
